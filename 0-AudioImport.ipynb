# %% [markdown]
# # Setup

# %% [markdown]
# ## Import Libraries
#
# To import an external library, use `!pip install`  or  `!apt-get install`

# %%
# The latest stable release is available on PyPI
# !pip install librosa

# %%
# Check if librosa is installed successfully
# Uncomment the line below to check if the libraries are installled
# !pip list

# %% [markdown]
# ## Load Files

# %% [markdown]
# Mount Google Drive in the runtime's virtual machine
#
# Other ways of using external data in Colab https://colab.research.google.com/notebooks/io.ipynb#scrollTo=c2W5A2px3doP

# %%
# Mount Google Drive on your runtime using an authorization code
from google.colab import drive
drive.mount('/content/drive')

# %%
# alias
# f = op
with open('/content/drive/My Drive/Speech_And_Audio_Demo/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/Speech_And_Audio_Demo/foo.txt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b2099c397928> in <module>()
# ----> 1 with open('/content/drive/My Drive/Speech_And_Audio_Demo/foo.txt', 'w') as f:
#       2   f.write('Hello Google Drive!')
#       3 get_ipython().system('cat /content/drive/My\\ Drive/Speech_And_Audio_Demo/foo.txt')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Speech_And_Audio_Demo/foo.txt'

# %%
y, sr = librosa.load(librosa.util())
