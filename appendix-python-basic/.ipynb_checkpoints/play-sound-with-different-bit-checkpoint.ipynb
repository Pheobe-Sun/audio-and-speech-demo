# %% [markdown]
# # 8 bit 16 bit 24 bit 64 bit

# %%
import soundfile as sf

# %% [markdown]
# #### Read audio file and change bit rate

# %%
x, Fs = sf.read('../audio/narration_short_44k_24bit_stereo.wav', dtype='int32') #  only 'float64', 'float32', 'int32' and 'int16' are supported
x

# TODO I somehow cannot playback sf.read files using IPython.display.Audio???? Warum??????
# Out:
# array([[    0,     0],
#        [  512,   768],
#        [-1536,     0],
#        ...,
#        [    0,     0],
#        [    0,     0],
#        [    0,     0]])

# %% [markdown]
# #### Write audio file

# %%
# sf.write('../output/filename.wav', x, Fs)

# %% [markdown]
# #### Plot signal

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,2))
plt.plot(x)
plt.xlim([0, x.shape[0]])
plt.xlabel('Time (samples)', fontsize=14)
plt.ylabel('Amplitude')
plt.tight_layout()
print(Fs)
# Out:
# 44100

# %% [markdown]
# #### Play signal

# %%
from IPython.display import Audio
import librosa

x_libro, Fs_libro = librosa.load('../audio/narration_short_44k_24bit_stereo.wav')
Audio(x_libro, rate=Fs_libro)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
